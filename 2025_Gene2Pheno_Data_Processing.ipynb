# %% [markdown]
# ### Notebook Purpose
#
# **Transform the gene-disease data from the G2P database to include additional mechanistic encoding columns in the form of LoF, GoF, DN, and a confidence score assessing the prediction.**

# %%
import pandas as pd
import numpy as np

# %%
# Section 1 -> Loading data

df = pd.read_csv("G2P_Eye_2025-03-08.csv")

df.head()
# Out:
#      g2p id gene symbol  gene mim  hgnc id       previous gene symbols  \
# 0  G2P00001        HMX1  142992.0     5017                  H6; NKX5-3
# 1  G2P00008        YAP1  606608.0    16262                YAP-1; YAP65
# 2  G2P00009        BBS9  607968.0    30000                   B1; PTHB1
# 3  G2P00010      TRIM32  602290.0    16380  BBS11; HT2A; LGMD2H; TATIP
# 4  G2P00011        PAX2  167409.0     8616                       PAX-2
#
#                                         disease name disease mim  \
# 0               HMX1-related oculoauricular syndrome      612109
# 1  YAP1-related coloboma, ocular, with or without...      120433
# 2                 BBS9-related Bardet-Biedl syndrome      615986
# 3               TRIM32-related Bardet-Biedl syndrome      615988
# 4                 PAX2-related papillorenal syndrome      120330
#
#   disease MONDO    allelic requirement cross cutting modifier  ...  \
# 0           NaN    biallelic_autosomal                    NaN  ...
# 1           NaN  monoallelic_autosomal                    NaN  ...
# 2           NaN    biallelic_autosomal                    NaN  ...
# 3           NaN    biallelic_autosomal                    NaN  ...
# 4           NaN  monoallelic_autosomal                    NaN  ...
#
#    variant consequence variant types molecular mechanism  \
# 0  absent gene product           NaN    loss of function
# 1  absent gene product           NaN    loss of function
# 2  absent gene product           NaN    loss of function
# 3            uncertain           NaN        undetermined
# 4  absent gene product           NaN    loss of function
#
#   molecular mechanism categorisation molecular mechanism evidence  \
# 0                           inferred                          NaN
# 1                           inferred                          NaN
# 2                           inferred                          NaN
# 3                           inferred                          NaN
# 4                           inferred                          NaN
#
#                                           phenotypes  \
# 0  HP:0000647; HP:0004328; HP:0000639; HP:0000482...
# 1  HP:0000407; HP:0003829; HP:0002006; HP:0001249...
# 2  HP:0007707; HP:0001773; HP:0001162; HP:0000750...
# 3  HP:0007707; HP:0001773; HP:0001162; HP:0000750...
# 4  HP:0000480; HP:0000588; HP:0002171; HP:0001144...
#
#                                         publications    panel comments  \
# 0                       18423520; 25574057; 29140751  DD; Eye      NaN
# 1                                 24462371; 27267789  DD; Eye      NaN
# 2                                 16380913; 22353939  DD; Eye      NaN
# 3                                           16606853  DD; Eye      NaN
# 4  9760197; 3377002; 11461952; 2644560; 7795640; ...  DD; Eye      NaN
#
#          date of last review
# 0  2019-09-26 16:23:46+00:00
# 1  2017-05-12 10:48:00+00:00
# 2  2025-01-21 22:09:55+00:00
# 3  2025-01-21 22:12:35+00:00
# 4  2015-07-22 16:14:08+00:00
#
# [5 rows x 21 columns]

# %%
# Section 2 -> Key/Column mapping.

mechanism_map = {
    "loss of function": (1, 0, 0),
    "gain of function": (0, 1, 0),
    "dominant negative": (0, 0, 1),
    "undetermined": (0, 0, 0)  # Default: No specific mechanism
}

confidence_map = {
    "definitive": 5,
    "strong": 4,
    "moderate": 3,
    "limited": 2,
    "disputed": 1,
    "refuted": 0
}

allelic_requirement_map = {
    "biallelic_autosomal": "AR",
    "monoallelic_autosomal": "AD",
    "monoallelic_X": "X-linked",
    "monoallelic_Y_hemizygous": "Y-linked",
    "mitochondrial": "mtDNA"
}

# %%
# Section 3 -> Helper functions.

def parse_mechanism_cat(mech_str):
    if pd.isna(mech_str):
        return (0, 0, 0)
    return mechanism_map.get(mech_str.strip().lower(), (0, 0, 0))

def parse_confidence(conf_str):
    if pd.isna(conf_str):
        return 0
    return confidence_map.get(conf_str.strip().lower(), 0)

def parse_allelic_requirement(ar_str):
    if pd.isna(ar_str):
        return ""
    return allelic_requirement_map.get(ar_str.strip(), ar_str)

def log_normalize(series):
    if series.max() == 0:
        return series  
    return np.log1p(series) / np.log1p(series.max())

# %%
# Section 4 -> DF transformation.

df["LoF"], df["GoF"], df["DN"] = zip(*df["molecular mechanism"].apply(parse_mechanism_cat))

df["ConfidenceScore"] = df["confidence"].apply(parse_confidence) if "confidence" in df.columns else 0

df["Mechanism_Vector_4D"] = df.apply(lambda row: np.array([
    row["LoF"],
    row["GoF"],
    row["DN"],
    row["ConfidenceScore"]
]), axis=1)

if "allelic requirement" in df.columns:
    df["AllelicReq_Simplified"] = df["allelic requirement"].apply(parse_allelic_requirement)

# %%
# Section 5 -> Result and export.

df[[
    "gene symbol",
    "disease name",
    "molecular mechanism",
    "LoF", "GoF", "DN",
    "ConfidenceScore",
    "Mechanism_Vector_4D"
]].head(20)

# df.to_csv("G2P_annotated.csv", index=False)
# Out:
#    gene symbol                                       disease name  \
# 0         HMX1               HMX1-related oculoauricular syndrome
# 1         YAP1  YAP1-related coloboma, ocular, with or without...
# 2         BBS9                 BBS9-related Bardet-Biedl syndrome
# 3       TRIM32               TRIM32-related Bardet-Biedl syndrome
# 4         PAX2                 PAX2-related papillorenal syndrome
# 5        FGFR3  FGFR3-related lacrimo-auriculo-dento-digital s...
# 6         FLNB  FLNB-related spondylocarpotarsal synostosis sy...
# 7         AGPS  AGPS-related rhizomelic chondrodysplasia punctata
# 8      RPGRIP1         RPGRIP1-related Leber congenital amaurosis
# 9        LAMA1  LAMA1-related cerebellar dysplasia with cysts ...
# 10         FTL  FTL-related hereditary hyperferritinemia-catar...
# 11      COL2A1                    COL2A1-related Kniest dysplasia
# 12        GJA1           GJA1-related Hallermann-Streiff syndrome
# 13        PLK4  PLK4-related microcephaly, growth failure and ...
# 14        CLN3        CLN3-related neuronal ceroid lipofuscinosis
# 15       FOXE3           FOXE3-related congenital primary aphakia
# 16        CLN8        CLN8-related neuronal ceroid lipofuscinosis
# 17        MKKS             MKKS-related Mckusick-Kaufman syndrome
# 18      LRPAP1                     LRPAP1-related myopia, extreme
# 19     SLC4A11  SLC4A11-related corneal endothelial dystrophy ...
#
#    molecular mechanism  LoF  GoF  DN  ConfidenceScore Mechanism_Vector_4D
# 0     loss of function    1    0   0                5        [1, 0, 0, 5]
# 1     loss of function    1    0   0                4        [1, 0, 0, 4]
# 2     loss of function    1    0   0                5        [1, 0, 0, 5]
# 3         undetermined    0    0   0                2        [0, 0, 0, 2]
# 4     loss of function    1    0   0                5        [1, 0, 0, 5]
# 5         undetermined    0    0   0                5        [0, 0, 0, 5]
# 6     loss of function    1    0   0                5        [1, 0, 0, 5]
# 7         undetermined    0    0   0                5        [0, 0, 0, 5]
# 8     loss of function    1    0   0                5        [1, 0, 0, 5]
# 9     loss of function    1    0   0                5        [1, 0, 0, 5]
# 10    loss of function    1    0   0                5        [1, 0, 0, 5]
# 11   dominant negative    0    0   1                5        [0, 0, 1, 5]
# 12        undetermined    0    0   0                2        [0, 0, 0, 2]
# 13    loss of function    1    0   0                5        [1, 0, 0, 5]
# 14    loss of function    1    0   0                5        [1, 0, 0, 5]
# 15    loss of function    1    0   0                5        [1, 0, 0, 5]
# 16    loss of function    1    0   0                5        [1, 0, 0, 5]
# 17    loss of function    1    0   0                5        [1, 0, 0, 5]
# 18    loss of function    1    0   0                5        [1, 0, 0, 5]
# 19    loss of function    1    0   0                4        [1, 0, 0, 4]
